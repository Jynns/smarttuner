# %%
import pyaudio as pa
import wave 
import struct
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
FORMAT =  pa.paInt16
CHANNELS = 2
RATE = 44100
CHUNK = 1024

# %%
p = pa.PyAudio()

# %%
stream = p.open(format = FORMAT,
                channels = CHANNELS,
                rate = RATE,
                input = True)

# %%
frames = []
frequency = 385.6

# %%
for i in range(0, int(RATE / CHUNK)):
    data = stream.read(CHUNK)
    data_converted = struct.unpack(str(4 * CHUNK) + 'B',data)
    data_np = np.array(data_converted, dtype='b')[::2] + 128
    frames.append(data_np)

# %%
fig, ax = plt.subplots(1, figsize=(15,7))
ax.set_xlim(2*CHUNK)
ax.plot(frames[2])

# %%
frames[0][:10]
# Out:
# array([193, 190, 189, 188, 185, 161, 189, 188, 190, 187], dtype=int16)

# %%
df = pd.DataFrame({'Data':[],'Frequency':[]})

# %%
for chunk in frames[:4]:
    df.append(data = [chunk,frequency])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fedcd19704bc> in <module>()
#       1 for chunk in frames[:4]:
# ----> 2     df.append(data = [ chunk,frequency])
#
# TypeError: append() got an unexpected keyword argument 'data'

# %%
list(frequency)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-9b00b9bcfa02> in <module>()
# ----> 1 list(frequency)
#
# TypeError: 'float' object is not iterable
